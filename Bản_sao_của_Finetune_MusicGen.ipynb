# %%
# !git clone https://github.com/facebookresearch/audiocraft.git
# %cd audiocraft
# !pip install -e .
# !pip install dora-search
# !pip install numba
# Out:
# fatal: destination path 'audiocraft' already exists and is not an empty directory.
# /content/audiocraft
# Obtaining file:///content/audiocraft
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: av==11.0.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (11.0.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.8.0)
# Requirement already satisfied: flashy>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.0.2)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (1.3.2)
# Requirement already satisfied: hydra_colorlog in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (1.2.0)
# Requirement already satisfied: julius in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.2.7)
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.5.13)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (1.26.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.2.0)
# Requirement already satisfied: spacy>=3.6.1 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (3.7.6)
# Requirement already satisfied: torch==2.1.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (2.1.0)
# Requirement already satisfied: torchaudio<2.1.2,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (2.1.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.24.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (4.66.5)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (4.44.2)
# Requirement already satisfied: xformers<0.0.23 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.0.22.post7)
# Requirement already satisfied: demucs in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (4.0.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.12.1)
# Requirement already satisfied: gradio in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (4.44.0)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (1.4.2)
# Requirement already satisfied: encodec in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.1.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (3.20.3)
# Requirement already satisfied: torchvision==0.16.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.16.0)
# Requirement already satisfied: torchtext==0.16.0 in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.16.0)
# Requirement already satisfied: pesq in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.0.4)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.10/dist-packages (from audiocraft==1.4.0a1) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0->audiocraft==1.4.0a1) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.16.0->audiocraft==1.4.0a1) (2.32.3)
# Requirement already satisfied: torchdata==0.7.0 in /usr/local/lib/python3.10/dist-packages (from torchtext==0.16.0->audiocraft==1.4.0a1) (0.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0->audiocraft==1.4.0a1) (10.4.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0->audiocraft==1.4.0a1) (12.6.68)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.7.0->torchtext==0.16.0->audiocraft==1.4.0a1) (2.2.3)
# Requirement already satisfied: dora-search in /usr/local/lib/python3.10/dist-packages (from flashy>=0.0.1->audiocraft==1.4.0a1) (0.1.12)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from flashy>=0.0.1->audiocraft==1.4.0a1) (6.8.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->audiocraft==1.4.0a1) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->audiocraft==1.4.0a1) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->audiocraft==1.4.0a1) (24.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (0.12.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (2.9.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (71.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=3.6.1->audiocraft==1.4.0a1) (3.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->audiocraft==1.4.0a1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->audiocraft==1.4.0a1) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->audiocraft==1.4.0a1) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->audiocraft==1.4.0a1) (0.19.1)
# Requirement already satisfied: lameenc>=1.2 in /usr/local/lib/python3.10/dist-packages (from demucs->audiocraft==1.4.0a1) (1.7.0)
# Requirement already satisfied: openunmix in /usr/local/lib/python3.10/dist-packages (from demucs->audiocraft==1.4.0a1) (1.3.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (3.7.1)
# Requirement already satisfied: fastapi<1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.115.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.27.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (6.4.5)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (3.7.1)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (3.10.7)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (2.1.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.0.10)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.6.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.12.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio->audiocraft==1.4.0a1) (0.30.6)
# Requirement already satisfied: websockets<13.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.3.0->gradio->audiocraft==1.4.0a1) (12.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->audiocraft==1.4.0a1) (1.0.8)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->audiocraft==1.4.0a1) (1.17.1)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words->audiocraft==1.4.0a1) (0.6.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics->audiocraft==1.4.0a1) (0.11.7)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->audiocraft==1.4.0a1) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->audiocraft==1.4.0a1) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->audiocraft==1.4.0a1) (1.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->audiocraft==1.4.0a1) (2.22)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi<1.0->gradio->audiocraft==1.4.0a1) (0.38.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->audiocraft==1.4.0a1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->audiocraft==1.4.0a1) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio->audiocraft==1.4.0a1) (0.14.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.6.1->audiocraft==1.4.0a1) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->audiocraft==1.4.0a1) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio->audiocraft==1.4.0a1) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio->audiocraft==1.4.0a1) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa->audiocraft==1.4.0a1) (4.3.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.6.1->audiocraft==1.4.0a1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.6.1->audiocraft==1.4.0a1) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.16.0->audiocraft==1.4.0a1) (3.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->audiocraft==1.4.0a1) (3.5.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.6.1->audiocraft==1.4.0a1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=3.6.1->audiocraft==1.4.0a1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.6.1->audiocraft==1.4.0a1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.6.1->audiocraft==1.4.0a1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3.6.1->audiocraft==1.4.0a1) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.6.1->audiocraft==1.4.0a1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.6.1->audiocraft==1.4.0a1) (7.0.4)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dora-search->flashy>=0.0.1->audiocraft==1.4.0a1) (1.3.4)
# Requirement already satisfied: submitit in /usr/local/lib/python3.10/dist-packages (from dora-search->flashy>=0.0.1->audiocraft==1.4.0a1) (1.5.2)
# Requirement already satisfied: treetable in /usr/local/lib/python3.10/dist-packages (from dora-search->flashy>=0.0.1->audiocraft==1.4.0a1) (0.2.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0->audiocraft==1.4.0a1) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.6.1->audiocraft==1.4.0a1) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio->audiocraft==1.4.0a1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.6.1->audiocraft==1.4.0a1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.6.1->audiocraft==1.4.0a1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.6.1->audiocraft==1.4.0a1) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from submitit->dora-search->flashy>=0.0.1->audiocraft==1.4.0a1) (2.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.6.1->audiocraft==1.4.0a1) (0.1.2)
# Installing collected packages: audiocraft
#   Attempting uninstall: audiocraft
#     Found existing installation: audiocraft 1.4.0a1
#     Uninstalling audiocraft-1.4.0a1:
#       Successfully uninstalled audiocraft-1.4.0a1
#   Running setup.py develop for audiocraft
# Successfully installed audiocraft-1.4.0a1
# Requirement already satisfied: dora-search in /usr/local/lib/python3.10/dist-packages (0.1.12)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.10/dist-packages (from dora-search) (2.3.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dora-search) (1.3.4)
# Requirement already satisfied: submitit in /usr/local/lib/python3.10/dist-packages (from dora-search) (1.5.2)
# Requirement already satisfied: treetable in /usr/local/lib/python3.10/dist-packages (from dora-search) (0.2.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from dora-search) (2.1.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from omegaconf->dora-search) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf->dora-search) (6.0.2)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dora-search) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from submitit->dora-search) (2.2.1)
# Requirement already satisfied: typing_extensions>=3.7.4.2 in /usr/local/lib/python3.10/dist-packages (from submitit->dora-search) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->dora-search) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->dora-search) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->dora-search) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->dora-search) (1.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.10/dist-packages (from numba) (1.26.4)

# %% [markdown]
# ##**Load Dataset into MusicGen**

# %%
use_existing_json = True

import os
import json
import random
import librosa

os.makedirs("/content/audiocraft/egs/train", exist_ok=True)
os.makedirs("/content/audiocraft/egs/eval", exist_ok=True)

dataset_folder = "/content/drive/MyDrive/preprocessed_dataset"
train_manifest_path = "/content/audiocraft/egs/train/data.jsonl"
eval_manifest_path = "/content/audiocraft/egs/eval/data.jsonl"

dataset_len = 0
train_len = 0
eval_len = 0

train_file = open(train_manifest_path, 'w')
eval_file = open(eval_manifest_path, 'w')

for filename in os.listdir(dataset_folder):
    if filename.endswith(".mp3"):
        dataset_len += 1

        entry = None

        if use_existing_json:
            base_filename = os.path.splitext(filename)[0]
            json_filepath = os.path.join(dataset_folder, base_filename + "_metadata.json")
            if os.path.exists(json_filepath):
                with open(json_filepath, 'r') as json_file:
                    entry = json.load(json_file)
                    entry["path"] = os.path.join(dataset_folder, filename)
            else:
                print(f'Error loading JSON: could not find {json_filepath}')
                continue
        else:
            y, sr = librosa.load(os.path.join(dataset_folder, filename))
            length = librosa.get_duration(y=y, sr=sr)

            entry = {
                "key": "",
                "artist": "",
                "sample_rate": 44100,
                "file_extension": "wav",
                "description": "",
                "keywords": "",
                "duration": length,
                "bpm": "",
                "genre": "cailuong",
                "title": "",
                "name": "",
                "instrument": "Mix",
                "moods": [],
                "path": os.path.join(dataset_folder, filename),
            }

        if entry:
            if random.random() < 0.85:
                train_len += 1
                train_file.write(json.dumps(entry) + '\n')
            else:
                eval_len += 1
                eval_file.write(json.dumps(entry) + '\n')

train_file.close()
eval_file.close()

print(f'dataset length: {dataset_len} audio clips')
print(f'train length: {train_len} audio clips')
print(f'eval length: {eval_len} audio clips')
# Out:
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/A5_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/CH_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/HE_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/G6_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/LB_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/MB_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/2C_metadata.json
# Error loading JSON: could not find /content/drive/MyDrive/preprocessed_dataset/7W_metadata.json
# dataset length: 808 audio clips
# train length: 684 audio clips
# eval length: 116 audio clips

# %%
config_path = "/content/audiocraft/config/dset/audio/train.yaml"

data_path = "egs/train"
eval_data_path = "egs/eval"

package = "package"
yaml_contents = f"""#@{package} __global__

datasource:
  max_channels: 2
  max_sample_rate: 44100

  evaluate: {eval_data_path}
  generate: {data_path}
  train: {data_path}
  valid: {eval_data_path}
"""

with open(config_path, 'w') as yaml_file:
    yaml_file.write(yaml_contents)

# %% [markdown]
# ##**Training MusicGen**

# %%
# %env USER=lyra

command = (
    "dora -P audiocraft run"
    " solver=musicgen/musicgen_base_32khz"
    " model/lm/model_scale=small"
    " continue_from=//pretrained/facebook/musicgen-small"
    " conditioner=text2music"
    " dset=audio/train"
    " dataset.num_workers=2"
    " dataset.valid.num_samples=1"
    " dataset.batch_size=2"
    " schedule.cosine.warmup=8"
    " optim.optimizer=adamw"
    " optim.lr=1e-4"
    " optim.epochs=10"
    " optim.updates_per_epoch=2000"
    " optim.adam.weight_decay=0.01"
    " generate.lm.prompted_samples=False"
    " generate.lm.gen_gt_samples=True"
)

# !{command}
# Out:
# env: USER=lyra
# 2024-09-25 16:54:46.169274: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 16:54:46.491686: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 16:54:46.577620: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 16:54:47.080355: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-25 16:54:49.768012: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Dora directory: /tmp/audiocraft_lyra
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# [09-25 16:54:55][dora.distrib][INFO] - world_size is 1, skipping init.
# [09-25 16:54:55][flashy.solver][INFO] - Instantiating solver MusicGenSolver for XP f02ffaa5
# [09-25 16:54:55][flashy.solver][INFO] - All XP logs are stored in /tmp/audiocraft_lyra/xps/f02ffaa5
# [09-25 16:54:55][audiocraft.solvers.builders][INFO] - Loading audio data split evaluate: /content/audiocraft/egs/eval
# [09-25 16:54:55][audiocraft.solvers.builders][INFO] - Loading audio data split generate: /content/audiocraft/egs/train
# [09-25 16:54:55][audiocraft.solvers.builders][INFO] - Loading audio data split train: /content/audiocraft/egs/train
# [09-25 16:54:55][audiocraft.solvers.builders][INFO] - Loading audio data split valid: /content/audiocraft/egs/eval
# [09-25 16:54:55][root][INFO] - Getting pretrained compression model from HF facebook/encodec_32khz
# config.json: 100% 758/758 [00:00<00:00, 4.07MB/s]
# model.safetensors: 100% 236M/236M [00:01<00:00, 131MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# [09-25 16:54:58][flashy.solver][INFO] - Compression model has 4 codebooks with 2048 cardinality, and a framerate of 50
# [09-25 16:54:58][audiocraft.modules.conditioners][INFO] - T5 will be evaluated with autocast as float32
# spiece.model: 100% 792k/792k [00:00<00:00, 5.58MB/s]
# tokenizer.json: 100% 1.39M/1.39M [00:00<00:00, 4.17MB/s]
# config.json: 100% 1.21k/1.21k [00:00<00:00, 7.62MB/s]
# model.safetensors: 100% 892M/892M [00:06<00:00, 129MB/s]
# [09-25 16:55:13][flashy.solver][INFO] - Model hash: 84d640e215de7863e944e465549d3e2e5faa07eb
# [09-25 16:55:13][flashy.solver][INFO] - Initializing EMA on the model with decay = 0.99 every 10 updates
# [09-25 16:55:13][flashy.solver][INFO] - Model size: 420.37 M params
# [09-25 16:55:13][flashy.solver][INFO] - Base memory usage, with model, grad and optim: 6.73 GB
# [09-25 16:55:13][flashy.solver][INFO] - Restoring weights and history.
# [09-25 16:55:13][flashy.solver][INFO] - Loading a pretrained model. Ignoring 'load_best' and 'ignore_state_keys' params.
# state_dict.bin: 100% 841M/841M [00:08<00:00, 103MB/s]
# [09-25 16:55:22][flashy.solver][INFO] - Checkpoint source is not the current xp: Load state_dict from best state.
# [09-25 16:55:22][flashy.solver][INFO] - Ignoring keys when loading best []
# [09-25 16:55:22][flashy.solver][INFO] - Loading state_dict from best state.
# [09-25 16:55:25][flashy.solver][INFO] - Re-initializing EMA from best state
# [09-25 16:55:25][flashy.solver][INFO] - Initializing EMA on the model with decay = 0.99 every 10 updates
# [09-25 16:55:27][flashy.solver][INFO] - Model hash: 776d041cbbcb8973c4968782a79f9bb63b53a727
# 2024-09-25 16:55:41.685899: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 16:55:41.685902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 16:55:41.721684: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 16:55:41.723015: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 16:55:41.732130: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 16:55:41.733426: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 16:55:44.667243: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 16:55:44.667532: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/audiocraft/audiocraft/solvers/musicgen.py:263: UserWarning: Up to version 1.0.1, the _prepare_tokens_and_attributes was evaluated with `torch.no_grad()`. This is inconsistent with how model were trained in the MusicGen paper. We removed the `torch.no_grad()` in version 1.1.0. Small changes to the final performance are expected. Really sorry about that.
#   warnings.warn(
# [09-25 16:55:56][audiocraft.modules.codebooks_patterns][INFO] - New pattern, time steps: 1500, sequence steps: 1504
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py:866: UserWarning: Synchronization debug mode is a prototype feature and does not yet detect all synchronizing operations (Triggered internally at ../torch/csrc/cuda/Module.cpp:816.)
#   torch._C._cuda_set_sync_debug_mode(debug_mode)
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:144: UserWarning: called a synchronizing CUDA operation (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:147.)
#   max_pad = max(padding_left, padding_right)
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:146: UserWarning: called a synchronizing CUDA operation (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:147.)
#   if length <= max_pad:
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:149: UserWarning: called a synchronizing CUDA operation (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:147.)
#   padded = nn.functional.pad(hidden_states, paddings, mode, value)
# /content/audiocraft/audiocraft/solvers/musicgen.py:237: UserWarning: called a synchronizing CUDA operation (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:147.)
#   ce_targets = targets_k[mask_k]
# /content/audiocraft/audiocraft/solvers/musicgen.py:238: UserWarning: called a synchronizing CUDA operation (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:147.)
#   ce_logits = logits_k[mask_k]
# [09-25 16:58:24][flashy.solver][INFO] - Train | Epoch 1 | 100/1000 | 0.57 it/sec | lr 9.55E-05 | grad_norm INF | grad_scale 18168.396 | ce 4.722 | ppl 151.489
# [09-25 17:00:50][flashy.solver][INFO] - Train | Epoch 1 | 200/1000 | 0.62 it/sec | lr 9.98E-05 | grad_norm 8.791E+00 | grad_scale 16384.000 | ce 4.729 | ppl 136.365
# [09-25 17:03:09][flashy.solver][INFO] - Train | Epoch 1 | 300/1000 | 0.65 it/sec | lr 9.94E-05 | grad_norm 6.223E+00 | grad_scale 16384.000 | ce 4.540 | ppl 117.181
# [09-25 17:05:27][flashy.solver][INFO] - Train | Epoch 1 | 400/1000 | 0.67 it/sec | lr 9.88E-05 | grad_norm 5.735E+00 | grad_scale 16384.000 | ce 4.571 | ppl 116.782
# [09-25 17:07:48][flashy.solver][INFO] - Train | Epoch 1 | 500/1000 | 0.68 it/sec | lr 9.81E-05 | grad_norm 5.398E+00 | grad_scale 16384.000 | ce 4.589 | ppl 115.834
# [09-25 17:10:05][flashy.solver][INFO] - Train | Epoch 1 | 600/1000 | 0.68 it/sec | lr 9.71E-05 | grad_norm 5.161E+00 | grad_scale 16384.000 | ce 4.569 | ppl 112.206
# [09-25 17:12:24][flashy.solver][INFO] - Train | Epoch 1 | 700/1000 | 0.69 it/sec | lr 9.60E-05 | grad_norm 4.778E+00 | grad_scale 16384.000 | ce 4.481 | ppl 104.068
# [09-25 17:14:51][flashy.solver][INFO] - Train | Epoch 1 | 800/1000 | 0.69 it/sec | lr 9.46E-05 | grad_norm 4.821E+00 | grad_scale 16384.000 | ce 4.337 | ppl 97.535
# [09-25 17:17:09][flashy.solver][INFO] - Train | Epoch 1 | 900/1000 | 0.69 it/sec | lr 9.31E-05 | grad_norm 4.214E+00 | grad_scale 16384.000 | ce 4.464 | ppl 102.413
# [09-25 17:19:28][flashy.solver][INFO] - Train Summary | Epoch 1 | lr=9.64E-05 | grad_norm=INF | grad_scale=16564.224 | ce=4.535 | ppl=114.728 | duration=1440.565
# 2024-09-25 17:19:41.731731: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:19:41.731942: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:19:41.765747: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:19:41.765747: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:19:41.776194: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:19:41.776290: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:19:43.700550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 17:19:43.707584: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 17:19:48][flashy.solver][INFO] - Valid Summary | Epoch 1 | ce=4.379 | ppl=79.741 | duration=19.396
# [09-25 17:19:48][flashy.solver][INFO] - New best state with ce=4.379 (was inf)
# [09-25 17:19:55][flashy.solver][INFO] - Model hash: 8c56af58f68a776865650e66566be2d09c13f6c6
# [09-25 17:20:43][audiocraft.utils.checkpoint][INFO] - Checkpoint saved to /tmp/audiocraft_lyra/xps/f02ffaa5/checkpoint.th
# 2024-09-25 17:20:55.457081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:20:55.457078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:20:55.496462: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:20:55.503893: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:20:55.506725: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:20:55.514153: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:20:57.463243: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 17:20:57.503928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 17:23:22][flashy.solver][INFO] - Train | Epoch 2 | 100/1000 | 0.64 it/sec | lr 8.96E-05 | grad_norm 4.122E+00 | grad_scale 16384.000 | ce 4.421 | ppl 96.996
# [09-25 17:25:43][flashy.solver][INFO] - Train | Epoch 2 | 200/1000 | 0.67 it/sec | lr 8.76E-05 | grad_norm 3.615E+00 | grad_scale 16384.000 | ce 4.311 | ppl 92.620
# [09-25 17:27:50][flashy.solver][INFO] - Train | Epoch 2 | 300/1000 | 0.71 it/sec | lr 8.55E-05 | grad_norm 3.623E+00 | grad_scale 16384.000 | ce 4.390 | ppl 93.783
# [09-25 17:30:08][flashy.solver][INFO] - Train | Epoch 2 | 400/1000 | 0.71 it/sec | lr 8.32E-05 | grad_norm 3.565E+00 | grad_scale 16384.000 | ce 4.189 | ppl 83.377
# [09-25 17:32:29][flashy.solver][INFO] - Train | Epoch 2 | 500/1000 | 0.71 it/sec | lr 8.08E-05 | grad_norm 3.289E+00 | grad_scale 16384.000 | ce 4.126 | ppl 80.789
# [09-25 17:34:52][flashy.solver][INFO] - Train | Epoch 2 | 600/1000 | 0.71 it/sec | lr 7.82E-05 | grad_norm 3.700E+00 | grad_scale 16384.000 | ce 4.171 | ppl 81.519
# [09-25 17:37:09][flashy.solver][INFO] - Train | Epoch 2 | 700/1000 | 0.71 it/sec | lr 7.56E-05 | grad_norm 3.088E+00 | grad_scale 16384.000 | ce 4.205 | ppl 83.498
# [09-25 17:39:28][flashy.solver][INFO] - Train | Epoch 2 | 800/1000 | 0.71 it/sec | lr 7.28E-05 | grad_norm 3.336E+00 | grad_scale 16384.000 | ce 4.190 | ppl 80.533
# [09-25 17:41:49][flashy.solver][INFO] - Train | Epoch 2 | 900/1000 | 0.71 it/sec | lr 7.00E-05 | grad_norm 3.267E+00 | grad_scale 16384.000 | ce 4.198 | ppl 79.474
# [09-25 17:44:20][flashy.solver][INFO] - Train Summary | Epoch 2 | lr=7.91E-05 | grad_norm=3.482E+00 | grad_scale=16384.000 | ce=4.226 | ppl=84.643 | duration=1416.292
# 2024-09-25 17:44:32.282463: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:44:32.318020: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:44:32.328130: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:44:32.711339: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:44:32.745621: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:44:32.756249: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:44:34.261830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 17:44:34.721382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 17:44:38][flashy.solver][INFO] - Valid Summary | Epoch 2 | ce=4.303 | ppl=73.904 | duration=18.083
# [09-25 17:44:38][flashy.solver][INFO] - New best state with ce=4.303 (was 4.379)
# [09-25 17:44:46][flashy.solver][INFO] - Model hash: 98e4522534d6741aef7caeccb89b41d9f6e77094
# [09-25 17:47:03][audiocraft.utils.checkpoint][INFO] - Checkpoint saved to /tmp/audiocraft_lyra/xps/f02ffaa5/checkpoint.th
# 2024-09-25 17:47:15.552950: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:47:15.553224: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 17:47:15.591450: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:47:15.593285: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 17:47:15.602871: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:47:15.604853: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 17:47:17.589400: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 17:47:17.618378: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 17:49:47][flashy.solver][INFO] - Train | Epoch 3 | 100/1000 | 0.62 it/sec | lr 6.41E-05 | grad_norm 3.059E+00 | grad_scale 31956.911 | ce 4.089 | ppl 74.142
# [09-25 17:52:05][flashy.solver][INFO] - Train | Epoch 3 | 200/1000 | 0.67 it/sec | lr 6.10E-05 | grad_norm 2.885E+00 | grad_scale 32768.000 | ce 3.984 | ppl 67.587
# [09-25 17:54:33][flashy.solver][INFO] - Train | Epoch 3 | 300/1000 | 0.67 it/sec | lr 5.79E-05 | grad_norm 3.121E+00 | grad_scale 32768.000 | ce 4.025 | ppl 67.747
# [09-25 17:56:51][flashy.solver][INFO] - Train | Epoch 3 | 400/1000 | 0.68 it/sec | lr 5.48E-05 | grad_norm 3.059E+00 | grad_scale 32768.000 | ce 3.910 | ppl 62.857
# [09-25 17:59:09][flashy.solver][INFO] - Train | Epoch 3 | 500/1000 | 0.69 it/sec | lr 5.17E-05 | grad_norm 2.716E+00 | grad_scale 32768.000 | ce 3.886 | ppl 61.592
# [09-25 18:01:28][flashy.solver][INFO] - Train | Epoch 3 | 600/1000 | 0.69 it/sec | lr 4.85E-05 | grad_norm 2.812E+00 | grad_scale 32768.000 | ce 4.069 | ppl 68.016
# [09-25 18:03:37][flashy.solver][INFO] - Train | Epoch 3 | 700/1000 | 0.71 it/sec | lr 4.54E-05 | grad_norm 2.805E+00 | grad_scale 32768.000 | ce 4.028 | ppl 67.164
# [09-25 18:05:56][flashy.solver][INFO] - Train | Epoch 3 | 800/1000 | 0.71 it/sec | lr 4.23E-05 | grad_norm 2.703E+00 | grad_scale 32768.000 | ce 3.828 | ppl 61.858
# [09-25 18:08:15][flashy.solver][INFO] - Train | Epoch 3 | 900/1000 | 0.71 it/sec | lr 3.92E-05 | grad_norm 2.720E+00 | grad_scale 32768.000 | ce 4.023 | ppl 63.706
# [09-25 18:10:38][flashy.solver][INFO] - Train Summary | Epoch 3 | lr=5.01E-05 | grad_norm=2.860E+00 | grad_scale=32686.080 | ce=3.979 | ppl=65.642 | duration=1414.820
# 2024-09-25 18:10:52.986456: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:10:53.030962: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:10:53.042273: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:10:53.154087: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:10:53.188632: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:10:53.200024: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:10:56.429022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 18:10:56.429022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 18:11:01][flashy.solver][INFO] - Valid Summary | Epoch 3 | ce=4.241 | ppl=69.468 | duration=22.732
# [09-25 18:11:01][flashy.solver][INFO] - New best state with ce=4.241 (was 4.303)
# [09-25 18:11:08][flashy.solver][INFO] - Model hash: 70c92684527a5445209f0a6e82b6357ac6908c09
# [09-25 18:14:29][audiocraft.utils.checkpoint][INFO] - Checkpoint saved to /tmp/audiocraft_lyra/xps/f02ffaa5/checkpoint.th
# 2024-09-25 18:14:41.132548: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:14:41.132669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:14:41.167152: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:14:41.167152: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:14:41.177593: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:14:41.177593: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:14:43.276984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 18:14:43.276984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 18:17:10][flashy.solver][INFO] - Train | Epoch 4 | 100/1000 | 0.63 it/sec | lr 3.32E-05 | grad_norm 2.623E+00 | grad_scale 32768.000 | ce 3.823 | ppl 57.656
# [09-25 18:19:39][flashy.solver][INFO] - Train | Epoch 4 | 200/1000 | 0.65 it/sec | lr 3.02E-05 | grad_norm 2.635E+00 | grad_scale 32768.000 | ce 3.948 | ppl 65.164
# [09-25 18:21:58][flashy.solver][INFO] - Train | Epoch 4 | 300/1000 | 0.67 it/sec | lr 2.74E-05 | grad_norm 2.533E+00 | grad_scale 32768.000 | ce 3.863 | ppl 56.429
# [09-25 18:24:07][flashy.solver][INFO] - Train | Epoch 4 | 400/1000 | 0.69 it/sec | lr 2.46E-05 | grad_norm 2.603E+00 | grad_scale 32768.000 | ce 3.848 | ppl 55.917
# [09-25 18:26:47][flashy.solver][INFO] - Train | Epoch 4 | 500/1000 | 0.68 it/sec | lr 2.20E-05 | grad_norm 2.566E+00 | grad_scale 32768.000 | ce 3.866 | ppl 57.003
# [09-25 18:29:06][flashy.solver][INFO] - Train | Epoch 4 | 600/1000 | 0.69 it/sec | lr 1.94E-05 | grad_norm 2.475E+00 | grad_scale 32768.000 | ce 3.923 | ppl 58.665
# [09-25 18:31:25][flashy.solver][INFO] - Train | Epoch 4 | 700/1000 | 0.69 it/sec | lr 1.70E-05 | grad_norm 2.471E+00 | grad_scale 32768.000 | ce 3.886 | ppl 56.101
# [09-25 18:33:44][flashy.solver][INFO] - Train | Epoch 4 | 800/1000 | 0.69 it/sec | lr 1.47E-05 | grad_norm 2.416E+00 | grad_scale 32768.000 | ce 3.761 | ppl 53.037
# [09-25 18:36:01][flashy.solver][INFO] - Train | Epoch 4 | 900/1000 | 0.70 it/sec | lr 1.25E-05 | grad_norm 2.419E+00 | grad_scale 32768.000 | ce 3.747 | ppl 51.966
# [09-25 18:38:18][flashy.solver][INFO] - Train Summary | Epoch 4 | lr=2.12E-05 | grad_norm=2.514E+00 | grad_scale=32768.000 | ce=3.843 | ppl=56.472 | duration=1428.689
# 2024-09-25 18:38:32.245536: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:38:32.245536: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:38:32.280176: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:38:32.280176: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:38:32.290548: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:38:32.293304: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:38:34.436432: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 18:38:34.436421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 18:38:40][flashy.solver][INFO] - Valid Summary | Epoch 4 | ce=4.199 | ppl=66.623 | duration=21.977
# [09-25 18:38:40][flashy.solver][INFO] - New best state with ce=4.199 (was 4.241)
# [09-25 18:38:46][flashy.solver][INFO] - Model hash: 00afde3d130d7ea96f2ca02d3b172a22973418c3
# [09-25 18:42:21][audiocraft.utils.checkpoint][INFO] - Checkpoint saved to /tmp/audiocraft_lyra/xps/f02ffaa5/checkpoint.th
# 2024-09-25 18:42:34.005644: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:42:34.073613: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:42:34.097949: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:42:34.155655: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-25 18:42:34.193870: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-25 18:42:34.204826: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-25 18:42:37.748506: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-09-25 18:42:37.748506: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [09-25 18:45:04][flashy.solver][INFO] - Train | Epoch 5 | 100/1000 | 0.62 it/sec | lr 8.68E-06 | grad_norm 2.404E+00 | grad_scale 63913.822 | ce 3.689 | ppl 49.152
# [09-25 18:47:22][flashy.solver][INFO] - Train | Epoch 5 | 200/1000 | 0.67 it/sec | lr 6.98E-06 | grad_norm 2.374E+00 | grad_scale 65536.000 | ce 3.694 | ppl 49.158
# [09-25 18:49:42][flashy.solver][INFO] - Train | Epoch 5 | 300/1000 | 0.68 it/sec | lr 5.47E-06 | grad_norm 2.343E+00 | grad_scale 65536.000 | ce 3.694 | ppl 50.261

# %%
from numba import cuda
device = cuda.get_current_device()
device.reset()

# %% [markdown]
# ##**Save, Load, and Export**

# %%
from audiocraft.utils import export
from audiocraft import train
sig = "aec0903f"
# from https://github.com/facebookresearch/audiocraft/blob/main/docs/MUSICGEN.md#importing--exporting-models
xp = train.main.get_xp_from_sig(sig)
export.export_lm(xp.folder / 'checkpoint.th', '/content/checkpoints/finetune/state_dict.bin')
export.export_pretrained_compression_model('facebook/encodec_32khz', '/content/checkpoints/finetune/compression_state_dict.bin')

# %%
from audiocraft.models import MusicGen
musicgen = MusicGen.get_pretrained('/content/checkpoints/finetune')

# %%
sig = "aec0903f"

command = (
    "dora run solver=musicgen/musicgen_base_32khz"
    " model/lm/model_scale=small"

    f" continue_from=//SIG/{sig}"

    f" continue_from=/tmp/audiocraft_lyra/xps/{sig}/checkpoint.th"

    " conditioner=text2music"
    " dset=audio/train"
    " dataset.num_workers=2"
    " dataset.valid.num_samples=1"
    " dataset.batch_size=2"
    " schedule.cosine.warmup=8"
    " optim.optimizer=adamw"
    " optim.lr=1e-4"
    " optim.epochs=5"
    " optim.adam.weight_decay=0.01"
)

# !{command}

# %%
import shutil
sig = "aec0903f"

source_path = f'/tmp/audiocraft_lyra/xps/{sig}/checkpoint.th'
destination_path = '/content/drive/MyDrive/musicgen_finetunes/checkpoints/new'
os.makedirs(destination_path, exist_ok=True)
shutil.copy(source_path, destination_path)

# %%
sig = "aec0903f"

try:
    # !{command}
except:
    import shutil
    source_path = f'/tmp/audiocraft_lyra/xps/{sig}/checkpoint.th'
    destination_path = '/content/drive/MyDrive/musicgen_finetunes/checkpoints/'
    os.makedirs(destination_path, exist_ok=True)
    shutil.copy(source_path, destination_path)

# %% [markdown]
# ##**Generate Samples**

# %%
from audiocraft.data.audio import audio_write
import IPython.display as ipd
from audiocraft.models import MusicGen
import numpy as np

musicgen = MusicGen.get_pretrained('/content/checkpoints/finetune')
musicgen.set_generation_params(duration=16)

# %%
wavs = musicgen.generate_unconditional(4)

for idx, one_wav in enumerate(wavs):
    audio_write(f'{idx}', one_wav.cpu(), musicgen.sample_rate, strategy="loudness", loudness_compressor=True)
    ipd.display(ipd.Audio(one_wav.cpu(), rate=32000))

# %%
wavs = musicgen.generate([
    'disco',
    'slide guitar bluegrass',
    'breakbeat, amen break',
    'epic orchestral strings'
])

for idx, one_wav in enumerate(wavs):
    audio_write(f'{idx}', one_wav.cpu(), musicgen.sample_rate, strategy="loudness", loudness_compressor=True)
    ipd.display(ipd.Audio(one_wav.cpu(), rate=32000))

# %%
# RUN THIS BEFORE RUNNING THE NEXT CELLS!
import julius, torch

def normalize_audio(audio_data):
    max_value = torch.max(torch.abs(audio_data))
    audio_data /= max_value
    return audio_data

def convert_audio_channels(wav: torch.Tensor, channels: int = 2) -> torch.Tensor:
    *shape, src_channels, length = wav.shape
    if src_channels == channels:
        pass
    elif channels == 1:
        wav = wav.mean(dim=-2, keepdim=True)
    elif src_channels == 1:
        wav = wav.expand(*shape, channels, length)
    elif src_channels >= channels:
        wav = wav[..., :channels, :]
    else:
        raise ValueError('The audio file has less channels than requested but is not mono.')
    return wav

def convert_audio(wav: torch.Tensor, from_rate: float, to_rate: float, to_channels: int) -> torch.Tensor:
    wav = julius.resample_frac(wav, int(from_rate), int(to_rate))
    wav = convert_audio_channels(wav, to_channels)
    return wav

def generate_audio_continuation(musicgen, sample, generation_length, segment_length=60, overlap=10):
    overlap_samples = overlap * 32000
    segment_samples = segment_length * 32000
    output = np.array([])
    output = np.concatenate((output, sample.cpu().squeeze().numpy().astype(np.float32)))
    init_length = len(output) / 32000

    while len(output) / 32000 < generation_length:
        musicgen.set_generation_params(duration=segment_length)
        prompt = torch.tensor(np.array([output[-overlap_samples:]]), dtype=torch.float32)
        res = musicgen.generate_continuation(prompt=prompt, prompt_sample_rate=32000)
        res = res.cpu().squeeze().numpy().astype(np.float32)
        output = np.concatenate((output, res[overlap_samples:]))

    return output

# %%
from google.colab import files
uploaded = files.upload()

input_audio_filename = next(iter(uploaded.keys()))
sample, sample_sr = torchaudio.load(input_audio_filename)
sample = normalize_audio(sample)
sample = convert_audio(sample, sample_sr, 32000, 1)

wav = generate_audio_continuation(musicgen, sample, 60)

audio_write('continuation', output.cpu(), musicgen.sample_rate, strategy="loudness", loudness_compressor=True)
ipd.display(ipd.Audio(output, rate=32000))

# %%
wavs = musicgen.generate_unconditional(4)

for idx, wav in enumerate(wavs):

    wav = generate_audio_continuation(musicgen, wav, 60)

    audio_write(f'{idx}', wav.cpu(), musicgen.sample_rate, strategy="loudness", loudness_compressor=True)
    ipd.display(ipd.Audio(wav.cpu(), rate=32000))

# %%
from audiocraft.models import MusicGen, MultiBandDiffusion
mbd = MultiBandDiffusion.get_mbd_musicgen()

wavs, tokens = musicgen.generate_unconditional(4, return_tokens=True)
wavs_diffusion = mbd.tokens_to_wav(tokens)

for idx, one_wav in enumerate(wavs):
    audio_write(f'{idx}', one_wav.cpu(), musicgen.sample_rate, strategy="loudness", loudness_compressor=True)
    audio_write(f'{idx}_diffusion', wavs_diffusion[idx].cpu(), musicgen.sample_rate, strategy="loudness", loudness_compressor=True)

    print('default decoder:')
    ipd.display(ipd.Audio(one_wav.cpu(), rate=32000))
    print('multiband diffusion:')
    ipd.display(ipd.Audio(wavs_diffusion[idx].cpu().cpu(), rate=32000))

# %%
# Stereo inference
from audiocraft.models import MusicGen
import IPython.display as ipd

model = MusicGen.get_pretrained("facebook/musicgen-stereo-medium")
model.set_generation_params(duration=8)

wavs = model.generate([
    'disco',
    'slide guitar bluegrass',
    'breakbeat, amen break',
    'epic orchestral strings'
])

for idx, one_wav in enumerate(wavs):
    ipd.display(ipd.Audio(one_wav.cpu(), rate=model.sample_rate))
